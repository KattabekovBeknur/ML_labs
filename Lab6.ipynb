# %%
import sklearn
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors = 2)

# %%
data_weather = pd.read_csv('szeged-weather.zip',nrows = 1000)

# %%
data_weather.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
T = data_weather["Temperature (C)"]

# %%
data_weather.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
Gamma = []
a = []
for i in range(len(T)-1):
    Gamma.append(i+1)
    a.append(i+1)

# %%
X = []
Y = []
for i in range(len(T)-1):
    X.append([T[i]])
    Y.append(T[i+1])

# %%
num = 0
den = 0
max_k = -111
while(True):
    g_mean=np.mean(Gamma)
    for i in range(len(X)):
        for j in range(len(X)):
            k1 = np.linalg.norm(np.array([X[i]]) - np.array([X[j]]))/abs((np.array([X[i]])-np.array([X[j]])))#norm euclidean divide by distance
            if max_k<k1:
                max_k=k1
        num+=Y[i]*Gamma[i]*np.dot(max_k,max_k.T)
        den+=Y[i]*np.dot(max_k,max_k.T)
    a[i]=num/den
    for i in range(len(X)):
        m = abs(a[i]-Y[i])
        Gamma[i]=np.dot(m,m.T)
    if np.linalg.norm(Gamma)>g_mean:
        model.fit(X,Y)
        break
# Out:
# C:\Users\migam\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide
#
# C:\Users\migam\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in greater
#   if __name__ == '__main__':
# C:\Users\migam\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in less
#   if __name__ == '__main__':

# %%
model.predict(8)
# Out:
# array([8.44444444])

# %%
Gamma
# Out:
# [69.81530864197535,
#  54.43160493827161,
#  27.972345679012353,
#  22.615308641975282,
#  17.827160493827154,
#  3.0044444444444447,
#  3.1407716049382652,
#  7.9649382716049315,
#  22.774104938271588,
#  36.200277777777764,
#  37.75419753086421,
#  33.64000000000005,
#  18.777777777777768,
#  23.792716049382737,
#  15.29679012345682,
#  0.3734567901234541,
#  2.102499999999993,
#  14.020864197530884,
#  34.287530864197535,
#  71.40249999999999,
#  96.3669444444444,
#  141.2136111111111,
#  163.84000000000003,
#  184.3560493827161,
#  227.6745679012345,
#  219.53361111111104,
#  393.80197530864183,
#  479.1234567901235,
#  493.3334567901235,
#  517.0570679012346,
#  538.2400000000001,
#  489.63854938271584,
#  431.7160493827161,
#  357.4200308641974,
#  311.32641975308644,
#  288.81114197530883,
#  287.490864197531,
#  287.30249999999995,
#  317.43361111111136,
#  395.3469444444447,
#  431.9469444444445,
#  484.0,
#  635.0399999999997,
#  780.5815123456791,
#  898.6671604938274,
# ...
